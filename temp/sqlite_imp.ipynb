# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, AIMessage, BaseMessage

from langgraph.graph.state import StateGraph, START, END
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.graph.message import add_messages

from typing import Annotated, TypedDict, List, Dict
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
llm_endpoint = HuggingFaceEndpoint(
    repo_id=os.getenv('hf_model'),
    provider='together'
    )
model = ChatHuggingFace(llm=llm_endpoint)

google_model = ChatGoogleGenerativeAI(model='gemini-3.1-flash-lite')

# %%
google_model.invoke( [HumanMessage(content='hello, my name is akai')])
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Hello Akai! It’s nice to meet you. How are you doing today? Is there anything I can help you with?', 'extras': {'signature': 'EnEKbwERTTIPSMy+MB0LLIJyY1IZB9fiW3VPkQJ2/9nbfgdRzdPjysW7rK7eYtftXACdUp3MfQhfy5zLSJSIrISmToeL8YLc9uccNqNCry+igbN3Objudt2/RwjJplMUmDb6GvIGeX4bPrlN4sXq7oHrZg=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a01e76-3f2b-7932-93ba-03f68a28415f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 27, 'total_tokens': 35, 'input_token_details': {'cache_read': 0}})

# %%
response = google_model.invoke( [HumanMessage(content='hello, my name is akai')])

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': "Hello Akai! It's nice to meet you. How can I help you today?", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a01e6f-712d-7440-95d0-fa368ca06b9d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 328, 'total_tokens': 336, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 309}})

# %%
response.content
# Out:
# [{'type': 'text',
#   'text': "Hello Akai! It's nice to meet you. How can I help you today?",
#   'extras': {'signature': '...'}}]

# %%
response.content[0]['text']
# Out:
# "Hello Akai! It's nice to meet you. How can I help you today?"

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, AIMessage, BaseMessage

from langgraph.graph.state import StateGraph, START, END
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.checkpoint.sqlite import SqliteSaver
from langgraph.graph.message import add_messages
import sqlite3

from typing import Annotated, TypedDict, List, Dict
from dotenv import load_dotenv
import os
load_dotenv()

llm_endpoint = HuggingFaceEndpoint(
    repo_id=os.getenv('hf_model'),
    provider='together'
    )
model = ChatHuggingFace(llm=llm_endpoint)

google_model = ChatGoogleGenerativeAI(model='gemini-3.1-flash-lite')

class ChatSchema(TypedDict):
    topic:str
    messages:Annotated[List[BaseMessage], add_messages]


def chat_node(state:ChatSchema):
    messages = state['messages']
    response = google_model.invoke(messages)
    return {'messages':[AIMessage(content=response.content)]}

# %%
conn = sqlite3.connect(database='temp.db',check_same_thread=False)

# %%
checkpointer = SqliteSaver(conn=conn)

# %%
stategraph = StateGraph(state_schema=ChatSchema)
# nodes
stategraph.add_node('chat_node',chat_node)

# edges
stategraph.add_edge(START,'chat_node')
stategraph.add_edge('chat_node',END)


workflow = stategraph.compile(checkpointer=checkpointer)

# %%
CONFIG = {'configurable':{'thread_id':'thread-01'}}

# %%
chat_response = workflow.invoke({'messages':HumanMessage(content='my name- fern, can you recall what was my previous question')},config=CONFIG)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
response = workflow.get_state(config=CONFIG)
response.values['messages']
# Out:
# [HumanMessage(content='what is capital of china', additional_kwargs={}, response_metadata={}, id='22317746-a096-4a73-8e04-40f77c46aabc'),
#  AIMessage(content=[{'type': 'text', 'text': 'The capital of China is **Beijing**.', 'extras': {'signature': 'EnEKbwERTTIPvGULnbnjpLnZQ7QlG3e7gu/P5UwbnsNPjlHLkhd5Dhs5Ik/uRsiue5GTpWg5o6QwXirMA5emer/kGnyW4CMvyU7X+wk+l06T49kKj4rjGNBGNwisUGjCmGo8zoeo0ApnKqWTsXzOs1L/lg=='}}], additional_kwargs={}, response_metadata={}, id='c34cef19-ac0b-416c-ab47-25fabea504ce', tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='my name- fern, can you recall what was my previous question', additional_kwargs={}, response_metadata={}, id='45403f86-ca03-4f24-82a2-d14bfd481481'),
#  AIMessage(content=[{'type': 'text', 'text': 'Hello, Fern! Your previous question was: **"what is capital of china"**', 'extras': {'signature': 'EnEKbwERTTIP43YSwkvhP50MAU7evWBFhApWEK54073si4NiLZMry1AMVwLBRm1MOH7gT8jw+NUXT2q+kONA0J5+r5pEyr4ToA3ooclryJMw6mV4lvX2f58NikZs0C2jOy+0ttaBaE7IroW2P2oexRx/Ug=='}}], additional_kwargs={}, response_metadata={}, id='0e71ab91-5335-4dc2-aeee-95a781b1ee99', tool_calls=[], invalid_tool_calls=[])]

# %%
response
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='what is capital of china', additional_kwargs={}, response_metadata={}, id='22317746-a096-4a73-8e04-40f77c46aabc'), AIMessage(content=[{'type': 'text', 'text': 'The capital of China is **Beijing**.', 'extras': {'signature': 'EnEKbwERTTIPvGULnbnjpLnZQ7QlG3e7gu/P5UwbnsNPjlHLkhd5Dhs5Ik/uRsiue5GTpWg5o6QwXirMA5emer/kGnyW4CMvyU7X+wk+l06T49kKj4rjGNBGNwisUGjCmGo8zoeo0ApnKqWTsXzOs1L/lg=='}}], additional_kwargs={}, response_metadata={}, id='c34cef19-ac0b-416c-ab47-25fabea504ce', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='my name- fern, can you recall what was my previous question', additional_kwargs={}, response_metadata={}, id='45403f86-ca03-4f24-82a2-d14bfd481481'), AIMessage(content=[{'type': 'text', 'text': 'Hello, Fern! Your previous question was: **"what is capital of china"**', 'extras': {'signature': 'EnEKbwERTTIP43YSwkvhP50MAU7evWBFhApWEK54073si4NiLZMry1AMVwLBRm1MOH7gT8jw+NUXT2q+kONA0J5+r5pEyr4ToA3ooclryJMw6mV4lvX2f58NikZs0C2jOy+0ttaBaE7IroW2P2oexRx/Ug=='}}], additional_kwargs={}, response_metadata={}, id='0e71ab91-5335-4dc2-aeee-95a781b1ee99', tool_calls=[], invalid_tool_calls=[])]}, next=(), config={'configurable': {'thread_id': 'thread-01', 'checkpoint_ns': '', 'checkpoint_id': '1f19d464-72f5-6dcd-8004-b0d0979b91ba'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-08-21T09:54:19.275412+00:00', parent_config={'configurable': {'thread_id': 'thread-01', 'checkpoint_ns': '', 'checkpoint_id': '1f19d464-0bc5-626d-8003-68227ddab75c'}}, tasks=(), interrupts=())

# %%
thread_ids = set()
for checkpoint in checkpointer.list(None):
    thread_ids.add(checkpoint.config['configurable']['thread_id'])

list(thread_ids)
# Out:
# ['thread-01']
